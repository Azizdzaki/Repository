# %%
# NIM/Nama : 19623246/Muhammad Azizdzaki Khrisnanurmuflih
# Tanggal : 16 November 2023
# Deskripsi : Penyelesaian Praktikum Pengenalan Komputasi Modul 5 Problem 1

import pandas as pd

df = pd.read_csv("spotify_songs2.csv")
df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
df.mode()
# Out:
#                  track_id track_name   track_artist  track_popularity  \
# 0  7BKLCZ1jbUBVqRi2FVlTVw     Poison  Martin Garrix               0.0
# 1                     NaN        NaN            NaN               NaN
# 2                     NaN        NaN            NaN               NaN
# 3                     NaN        NaN            NaN               NaN
# 4                     NaN        NaN            NaN               NaN
#
#            track_album_id track_album_name track_album_release_date  \
# 0  5L1xcowSxwzFUSJzvyMp48    Greatest Hits               2020-01-10
# 1                     NaN              NaN                      NaN
# 2                     NaN              NaN                      NaN
# 3                     NaN              NaN                      NaN
# 4                     NaN              NaN                      NaN
#
#      playlist_name             playlist_id playlist_genre  ...  key  loudness  \
# ...

# %%
favorite_songs = df. sort_values (["track_popularity"], ascending =[1])
df.plot(kind="bar",x="favorite_songs",y="playlist_genre",title="3 Favorite Songs")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Coding\Tugas Besar 2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Coding/Tugas%20Besar%202.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df.plot(kind="bar",x="track_popularity",y="playlist_genre",title="3 Favorite Songs")
#
# File c:\Users\Zeech\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Zeech\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
# ...

# %%
df.plot(kind="scatter", x="track_popularity", y="danceability")
# Out:
# <Axes: xlabel='track_popularity', ylabel='danceability'>

# %%
df.plot(kind="scatter", x="track_popularity", y="loudness")
# Out:
# <Axes: xlabel='track_popularity', ylabel='loudness'>

# %%
df.plot(kind="scatter", x="track_popularity", y="liveness")
# Out:
# <Axes: xlabel='track_popularity', ylabel='liveness'>

# %%
df.plot(kind="scatter", x="track_popularity", y="tempo")
# Out:
# <Axes: xlabel='track_popularity', ylabel='tempo'>
